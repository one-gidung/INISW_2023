# %% [markdown]
# # 연습문제
#
# **1. 머신러닝을 어떻게 정의할 수 있나요?**\
# : 기계학습. 인간이 원하는 대로 기계를 학습시켜 결과를 보는 것\
# : _기계학습은 데이터에서부터 학습하도록 컴퓨터를 프로그래밍하는 과학이다._
#
# **2. 머신러닝이 도움을 줄 수 있는 문제 유형 네 가지를 말해보세요.**\
# : 모르겠음\
# : _기존 솔루션으로는 많은 수동 조정과 규칙이 필요한 문제: 하나의 머신러닝 모델이 코드를 간단하게 만들고 전통적인 방법보다 더 잘 수행되도록 할 수 있다._ \
# : _전통적인 방식으로는 해결 방법이 없는 복잡한 문제: 가장 뛰어난 머신러닝 기법으로 해결 방법을 찾을 수 있습니다._ \
# : _유동적인 환경: 머신러닝 시스템은 새로운 데이터에 적응할 수 있습니다._ \
# : _복잡한 문제와 대량의 데이터에서 통찰 얻기_
#
# **3. 레이블된 훈련 세트란 무엇인가요?**\
# : label이 매겨진 훈련 set, 즉 정답이 있는 지도학습에 사용되는 데이터. 분류문제.
# : _정답이 있는 훈련 세트를 말함_
#
# **4. 가장 널리 사용되는 지도 학습 작업 두 가지는 무엇인가요?**\
# : 분류, 추천?\
# : _분류, 예측_
#
# **5. 보편적인 비지도 학습 작업 네 가지는 무엇인가요?**\
# : 회귀, 군집, ...분류.. 추천..\
# : _군집, 이상치 탐지, 특이치 탐지, 시각화와 차원 축소, 연관 규칙 학습_
#
# **6. 사전 정보가 없는 여러 지형에서 로봇을 걸어가게 하려면 어떤 종류의 머신러닝 알고리즘을 사용할 수 있나요?**\
# : 강화학습을.. 하고 싶은데?, divide and quanau? DQ 쓰거나. 아니면 DP? 다이내믹 프로그래밍\
# : _강화학습_
#
# **7. 고객을 여러 그룹으로 분할하려면 어떤 알고리즘을 사용해야 하나요?**\
# : 정답이 없는 상태로 비지도 학습, 군집을 이루게 해야함. 그러면 거리기반 KNN쓰거나 K-means를 사용할 듯 싶다.\
# : _계층군집분석_
#
# **8. 스팸 감지의 문제는 지도 학습과 비지도 학습 중 어떤 문제로 볼 수 있나요?**\
# : 지도 학습\
# : _지도 학습_
#
# **9. 온라인 학습 시스템이 무엇인가요?**\
# : 모름\
# : _데이터를 순차적으로 한 개씩 또는 미니배치라 부르는 작은 묶음 단위로 주입하여 시스템을 훈련시킨다._ \
# :
#
# **10. 외부 메모리 학습이 무엇인가요?**\
# : 모름\
# : _컴퓨터 한 대의 메인 메모리에 들어갈 수 없는 아주 큰 데이터셋을 학습하는 시스템에 사용하는 온라인 학습을 말한다._
#
# **11. 예측을 하기 위해 유사도 측정에 의존하는 학습 알고리즘은 무엇인가요?**\
# : 추천 알고리즘\
# : _사례 기반 학습_\
#
#
# **12. 모델 파라미터와 학습 알고리즘의 하이퍼파라미터 사이에는 어떤 차이가 있나요?**\
# : 같은 데이터일 때 모델의 파라미터를 조정해 모델 성능을 높이거나\
# 같은 모델에 학습 알고리즘의 하이퍼파라미터 튜닝을 통해 데이터에 적절한 알고리즘을 선정하는 것에 차이가 있다. \
# : _학습 알고리즘을 통해 비용 함수를 최소화하는 모델 파라미터를 찾는다._ \
# : _학습 알고리즘의 파라미터는???_
#
#
# **13. 모델 기반 알고리즘이 찾는 것은 무엇인가요? 성공을 위해 이 알고리즘이 사용하는 가장 일반적인 전략은 무엇인가요? 예측은 어떻게 만드나요?**\
# : 모름\
# : 모름\
# : 예측은 유사도를 측정하거나 회귀선을 그려서 예측을 하지 않을까?\
# :_샘플로부터 일반화시키는 것이다._ \
# : _선형 회귀에서는 보통 선형 모델의 예측과 훈련 데이터 사이의 거리를 재는 비용 함수를 사용하고, 이 거리를 최소화하는 것이 목표이다._ \
# : _알고리즘에 훈련 데이터를 공급하면 데이터에 가장 잘 맞는 선형 모델의 파라미터를 찾아 이 모델을 사용해 예측을 한다._
#
# **14. 머신러닝의 주요 도전 과제는 무엇인가요?**\
# : 모델의 일반화, 즉 모델 훈련이나 테스트에 사용된 데이터가 아닌 실제 데이터에서도 적용이 될 수 있는가에 대한 문제\
# : _충분하지 않은 훈련 데이터, 좋은 알고리즘도 중요하지만 그만큼 좋은 데이터도 중요하다. 그 둘 사이의 트레이드 오프 관계를 고려해야한다. 또한 좋은 데이터를 많이 모으는 것은 쉬운 일이 아니기에 아직은 알고리즘을 계속 신경써야 한다는 점이다._ \
# : _대표성이 없는 훈련 데이터, 일반화하려면 사례들을 대표하는 훈련 세트를 사용하는 것이 매우 중요하다. 하지만 샘플이 작으면 __생픔링 잡음__(우연에 의한 대표성 없는 데이터)이 생기고, 매우 큰 샘플도 추출 방법이 잘못되면 대표성을 띠지 못하는 __샘플링 편향__ 이 있을 수 있다._ \
# : 낮은 품질의 데이터, 관련 없는 특성, 훈련 데이터 과대적합.과소적합
#
# **15. 모델이 훈련 데이터에서의 성능은 좋지만 새로운 샘플에서의 일반화 성능이 나쁘다면 어떤 문제가 있는 건가요? 가능한 해결책 세 가지는 무엇인가요?**\
# : 과적합 문제지. 오버피팅 문제.\
# : 모르겠다\
# : _오버 피팅 문제_ \
# : _파라미터 수가 적은 모델을 선택하거나(예를 들면 고차원 다항 모델보다 선형 모델), 훈련 데이터에 있는 특성 수를 줄이거나, 모델에 제약을 가하여 단순화시킨다._ \
# : _훈련 데이터를 더 많이 모은다._ \
# : _훈련 데이터의 잡음을 줄인다.(ex: 오류 데이터 수정과 이상치 제거)_
#
# **16. 테스트 세트가 무엇이고 왜 사용해야 하나요?**\
# : 훈련시킨 모델이 얼마나 일반화가 잘 되었는지. 오버피팅은 안 되었는지. 학습은 잘 되었는지 확인하기 위해 별도로 분리한 데이터.\
# 학습에 사용하지 않음(사용하면 안 됨)
# : _모델을 테스트하는 데이터로 모델을 평가함으로써 일반화 오차(새로운 샘플에 대한 오류 비율, 외부 샘플 오차)에 대한 추정값을 얻는다._ \
# : _훈련 오차가 낮더라도 일반화 오차가 높다면 이는 모델이 훈련 데이터에 과대적합되었다는 뜻으로 새로운 샘플이 모델이 얼마나 잘 작동할지 알려준다._
#
# **17. 검증 세트의 목적은 무엇인가요?**\
# : 테스트 데이터보다 한단계 더 나아가서 얼마나 실 데이터. 일반화에 적용될 수 있는지를 판단하는 척도로 사용된다.\
# : _검증 세트의 목적은 데이터 불일치를 판별한다._
#
# **18. 훈련-개발 세트가 무엇인가요? 언제 필요하고 어떻게 사용해야 하나요?**\
# 훈련은 모델 훈련시키는 데 쓰는 데이터 set 같고,, 개발...은 뭐지?\
# : _훈련-개발 세트는 훈련 세트에서 일부를 분리한 것이다. 이 결과로 훈련 세트의 과대적합을 판별한다._
#
# **19. 테스트 세트를 사용해 하이퍼파라미터를 튜닝하면 어떤 문제가 생기나요?**\
# : 테스트 데이터에서만 학습이 되어 오버피팅이 될 가능성이 커진다.\
# 검증하기 위해 분리한 데이터인데 이를 이용해 하이퍼파라미터 튜닝을 하면 테스트 세트를 분리한 의미가 없어진다.

# %% [markdown]
# # 1.1 머신러닝이란?
# - 머신러닝은 데이터에서부터 학습하도록 컴퓨터를 프로그래밍하는 과학이다.
# - 머신러닝은 명시적인 프로그래밍 없이 컴퓨터가 학습하는 능력을 갖추게 하는 연구 분야다.
# - 어떤 작업 T에 대한 컴퓨터 프로그램의 성능을 P로 측정했을 때 경험 E로 인해 성능이 향상됐다면, 이 컴퓨터 프로그램은 작업 T와 성능 측정 P에 대해 경험 E로 학습한 것이다.
#
# 훈련 세트(training set): 시스템이 학습하는 데 사용하는 샘플\
# 훈련 사례(training instance): 각 훈련 데이터
#
# # 1.2 왜 머신러닝을 사용하는가?
