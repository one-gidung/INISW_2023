# %%
import antigravity

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # 기본 연산자

# %%
2+2
# Out:
# 4

# %%
50 - 5*6
# Out:
# 20

# %%
(50 - 5*6)/4
# Out:
# 5.0

# %% [markdown]
# 나눗셈

# %%
8/5 # 나눗셈은 언제나 float형을 return해준다.
# Out:
# 1.6

# %%
17/3 # clasic division returns a float
# Out:
# 5.666666666666667

# %% [markdown]
# 나눗셈의 정수 결과 얻기

# %%
17//3 # floor division discards thr fractional part
# Out:
# 5

# %% [markdown]
# 나눗셈의 나머지 얻기

# %%
17%3 # the % operator returns the remainder of the division
# Out:
# 2

# %%
5 * 3 + 2 # result * divisor + remainder
# Out:
# 17

# %% [markdown]
# 거듭제곱: \*\*연산자

# %%
5**2 # 5 squared
# Out:
# 25

# %%
2**7 # 2 to the power of 7
# Out:
# 128

# %% [markdown]
# - 파이썬에서는 변수보다는 식벽자(identifier) 또는 이름(name)으로 통칭한다. 이는 파이썬의 모든 값은 객체이기 때문이다.
#
# - 등호를 사용하여 값을 할당하는 것(이름 붙이는 것)을 binding, assignment라고 하고, 이에 관한 문장(statement)을 대입문이라고한다.
#
# - 같은 이름에 다시 할당하는 것을 재할당이라고하고, 재할당할 수 없는 값을 보통 상수라고 한다. 파이선에서는 기본적으로 상수가 존재하지 않는다.\
# (C의 const, Java의 Final과 같은 상수를 정의하는 키워드가 없음).

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
width = 20

# %%
height = 5*9

# %%
17/3 # classic division returns a float
# Out:
# 5.666666666666667

# %%
width*height
# Out:
# 900

# %% [markdown]
# - 변수가 <<정의되어>> 있지 않을 때 (값을 대입하지 않았을 때) 사용하려고 시도하는 것은 네임에러(NameError)를 일으킨다.

# %%
n # try to access an undefined variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36992/528237361.py in <module>
# ----> 1 n # try to access an undefined variable
#
# NameError: name 'n' is not defined

# %% [markdown]
# - **기본적으로 파이썬의 변수 정의는 C언어와 달리 선언만으로 가능하지 않고, 선언과 동시에 할당이 이루어져야 한다. 내부적인 구조는 다음의 그림에서 알 수 있다.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - **파이썬에서 이름을 정하는 규칙이 있다.**
#     1. 키워드로 이름을 사용할 수 없다.
#     2. \_을 제외, 숫자나 특수 문자가 이름의 첫 단어로 올 수가 없다.\
#     (\_로 시작하는 이름은 특별한 의미를 가진다)
#     3. 이 외 모든 유니코드 문자를 사용할 수 있으나, 호환성을 위해서 ASCII 코드를 이름에 사용하는 것이 권장된다.
# ---
# - **파이썬에서 키워드는 \
# import keyword\
# print(keysord.kwlist)\
# 로 확인할 수 있다. 키워드는 파이썬 버전별로 상이할 수 있다.**
#
# ---
# * 키워드(예약어, Reserved Words): 이미 사용되고 있는(용도가 예약된) 단어들로, 이미 문법적인 용도로 사용

# %% [markdown]
# # 코어션(coercion)

# %%
4 * 3.75 - 1
# Out:
# 14.0

# %% [markdown]
# - 서로 다른 형의 피연산자를 갖는 연산자는 정수 피연산자를 실수로 변환합니다.
# - 이러한 변환을 coercion(코어션)이라고 한다. 코어션이란 같은 형의 두 인자를 수반하는 연산이 일어나는 동안, 한 형의 인스턴스를 다른 형으로 묵시적으로 변환하는 것. 예를 들어, int(3.15)는 실수를 정수 3으로 변환한다. 하지만, 3+4.5에서, 각 인자는 다른 형이고(하나는 int, 다른 하나는 float), 둘을 더하기 전에 같은 형으로 변환해야 한다. 그렇지 않으면 TypeError를 일으킵니다. 코어션 없이는, 호화노디는 형들조차도 프로그래머가 같은 형으로 정규화해주어야 한다. 예를 들어, 그냥 3+4.5 하는 대신 float(3)+4.5

# %% [markdown]
# # 변수 _

# %% [markdown]
# <u>**대화형 모드**</u>에서는, 마지막에 인쇄된 표현식은 변수 \_에 대입됩니다.

# %%
tax = 12.5/100

# %%
price = 100.50

# %%
price*tax
# Out:
# 12.5625

# %%
price + _
# Out:
# 113.0625

# %%
round(_, 2)
# Out:
# 113.06

# %% [markdown]
# <u>이 변수는 사용자로서는 읽기만 가능한 것처럼 취급되어야 합니다. 값을 직접 대입하지 마세요, 만약 그렇게 한다면 같은 이름의 지역 변수를 새로 만드는 것이 되는데, 내장 변수의 마술 같은 동작을 차단하는 결과를 낳습니다.</u>

# %% [markdown]
# * 파이썬의 기본(builtin) 숫자형은 4가지이고 모두 불변 객체이다.
#     1. int
#     2. float
#     3. complex (복소수)
#     4. bool (True, False)\
#     파이썬의 bool형은 int를 상속해서 정의함.

# %% [markdown]
# # 문자열

# %%
'"Isn\'t," they said'
# Out:
# '"Isn\'t," they said'

# %%
print('"Isn\'t," they said')
# Out:
# "Isn't," they said

# %%
s = 'First line.\nSecond line.'

# %%
s
# Out:
# 'First line.\nSecond line.'

# %%
print(s)
# Out:
# First line.
# Second line.

# %% [markdown]
# \뒤에 나오는 문자가 특수문자로 취급되게 하고 싶지 않다면, 첫 따옴표 앞에 r을 붙여서 날 문자열(raw string)을 만들 수 있습니다.

# %%
print('C:\some\name')
# Out:
# C:\some
# ame

# %%
print(r'C:\some\name')
# Out:
# C:\some\name

# %%
print("""\
Usage: thingy [OPTION]
    -h                       Display this usage message
    -H hostname              Hostname to connect to
""")
# Out:
# Usage: thingy [OPTION]
#     -h                       Display this usage message
#     -H hostname              Hostname to connect to

# %% [markdown]
# * 파이썬에서는 숫자형을 제외하고 * 연산자는 반복을 시키는 용도로 사용할 수 있다.\
#
# 두 개 이상의 문자열 리터럴(즉, 따옴표로 둘러쌰인 것들)이 연속해서 나타나면 자동으로 이어 붙여진다.

# %%
# 오직 두 개의 리터럴에만 적용된다.
'Py''thon'
# Out:
# 'Python'

# %%
text = ('한소희는 얼굴이 '
       '너무 예쁘다')

# %%
text
# Out:
# '한소희는 얼굴이 너무 예쁘다'

# %%
prefix = '한'

# %%
# 변수에서는 적용 안 된다
prefix '소희'
# Out:
#   File "C:\Users\dlel2\AppData\Local\Temp/ipykernel_33560/2610612766.py", line 1
#     prefix '소희'
#            ^
# SyntaxError: invalid syntax

# %%
# 표현식에서도 적용 안 된다.
('한'*3)'소희'
# Out:
#   File "C:\Users\dlel2\AppData\Local\Temp/ipykernel_33560/915691227.py", line 1
#     ('한'*3)'소희'
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# 변수들끼리 혹은 변수와 문자열 리터럴을 이어붙이려면 +를 사용해야 합니다.

# %%
prefix + '소희'
# Out:
# '한소희'

# %%
word = "한소희"

# %%
len(word)
# Out:
# 3

# %% [markdown]
# **너무 큰 값을 인덱스로 사용하면 IndexError가 난다.**

# %%
word[43]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33560/3451096127.py in <module>
# ----> 1 word[43]
#
# IndexError: string index out of range

# %% [markdown]
# **하지만, 범위를 벗어나는 슬라이스 인덱스는 슬라이싱할 때 부드럽게 처리된다.**

# %%
word[:43]
# Out:
# '한소희'

# %%
word[43:]
# Out:
# ''

# %% [markdown]
# ---
# 파이썬 문자열은 변경할 수 없다. (불변, immutable)\
# 그래서 문자열의 인덱스로 참조한 위치에 대입하려고 하면 Type에러를 일으킨다.\
# 다른 문자열이 필요하면, 새로 만들어야 한다.
#
# ---

# %%
word[0] = '김'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33560/2487336774.py in <module>
# ----> 1 word[0] = '김'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 리스트
# 파이썬은 다른 값들을 덩어리로 묶는데 사용되는 여러 가지 **<u>컴파운드 (compound) 자료형</u>** 이 있다.\
# - 리스트는 서로 다른 형의 항목들을 포함할 수 있지만, 항목들이 모두 같은 형인 경우가 많다.
# - 문자열(다른 모든 내장 시퀀스 형들)처럼 인덱싱하고 슬라이싱할 수 있다.
# - **<u>모든 슬라이스 연산은 요청한 항목들을 포함하는 새 리스트를 돌려준다.</u>**
# - 즉 리스트의 **<u>새로운 얕은 복사본</u>** 을 돌려준다는 뜻이다.
# - 불변인 문자열과 달리, 리스트는 가변이다. (mutable)

# %%
squares = [1,4,9,16,25]

# %%
squares
# Out:
# [1, 4, 9, 16, 25]
